# %%
import pandas as pd
import numpy as np
from collections import Counter
from vincenty import vincenty
from copy import deepcopy
from glob import glob
from pprint import pprint

# %%
colnames = ['lat','long', 'null', 'alt' ,'DateTime','Date','Time']
df = pd.read_csv('/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/013/Trajectory/20080929001436.plt', skiprows=6, names = colnames)

# %%
df.head()
# Out:
#          lat        long  null  alt      DateTime        Date      Time
# 0  39.647024  118.161976     0  492  39720.010139  2008-09-29  00:14:36
# 1  39.647015  118.161972     0  492  39720.010174  2008-09-29  00:14:39
# 2  39.647052  118.161963     0  492  39720.010208  2008-09-29  00:14:42
# 3  39.647115  118.161961     0  492  39720.010243  2008-09-29  00:14:45
# 4  39.647114  118.161939     0  492  39720.010278  2008-09-29  00:14:48

# %%
def add_feat(df_input):
    df = df_input
    # add some initial shifts
    df['lat_shift'] = df.lat.shift(-1)
    df['long_shift'] = df.long.shift(-1)
    df['time_shift'] = df.DateTime.shift(-1)
    # add speed
    def speed(x):
        try:
            s = vincenty((x[-3],x[-2]),(x[0],x[1]), miles = True) / ((x[-1]-x[4]) * 24)
        except:
            s= np.nan
        return s
    df['speed_mph'] = df.apply(speed,axis =1)
    df['speed_shift'] = df.speed_mph.shift(-1)
    # add acceleration
    def accel(x):
        try:
            a = (x[-1] - x[-2]) / ((x[9] - x[4]) *24)
        except:
            a = np.nan
        return a
    df['acceleration'] = df.apply(accel, axis =1)
    df['acceleration_shift'] = df.acceleration.shift(-1)
    # add jerk
    def jerk(x):
        try:
            j = (x[-1] - x[-2]) / ((x[9] - x[4]) *24)
        except:
            j = np.nan
        return a
    df['jerk'] = df.apply(accel, axis =1)
    df['jerk_shift'] = df.jerk.shift(-1)

    def y(x):
        try:
            yy = np.sin((x[8] - x[0]) * np.pi/180) *np.cos( x[7]* np.pi/180)
        except:
            yy= np.nan
        return yy
    df['y'] = df.apply(y, axis =1)

    def x(x):
        try:
            xx = np.cos(x[0] * np.pi/180) *np.sin(x[7]* np.pi/180) - np.sin(x[0]* np.pi/180) * np.cos(x[7]* np.pi/180)*np.cos((x[8]-x[1])* np.pi/180)
        except:
            xx = np.nan
        return xx
    df['x'] = df.apply(x,axis =1)

    def bearing(x):
        try:
            b = np.arctan2(x[-2],x[-1])*180/np.pi
        except:
            b = np.nan
        return b
    df['bearing'] = df.apply(bearing,axis=1)

    df['brearing_shift'] = df.bearing.shift(-1)

    def bearing_rate(x):
        try:
            br = abs(x[-1]-x[-2])
        except:
            br = np.nan
        return br
    df['bearing_rate'] = df.apply(bearing_rate,axis=1)
    return df

# %%
df = add_feat(df)

# %%
df.head()
# Out:
#          lat        long  null  alt      DateTime        Date      Time  \
# 0  39.647024  118.161976     0  492  39720.010139  2008-09-29  00:14:36
# 1  39.647015  118.161972     0  492  39720.010174  2008-09-29  00:14:39
# 2  39.647052  118.161963     0  492  39720.010208  2008-09-29  00:14:42
# 3  39.647115  118.161961     0  492  39720.010243  2008-09-29  00:14:45
# 4  39.647114  118.161939     0  492  39720.010278  2008-09-29  00:14:48
#
#    lat_shift  long_shift    time_shift  ...  speed_shift  acceleration  \
# 0  39.647015  118.161972  39720.010174  ...     3.116401   2793.602981
# 1  39.647052  118.161963  39720.010208  ...     5.217589   2521.426247
# 2  39.647115  118.161961  39720.010243  ...     1.410001  -4569.096021
# 3  39.647114  118.161939  39720.010278  ...    12.903608  13792.336673
# 4  39.646963  118.161889  39720.010313  ...     1.914001 -13187.535942
#
#    acceleration_shift          jerk    jerk_shift         y             x  \
# 0         2521.426247 -3.266123e+05 -8.508630e+06  0.754572 -1.570796e-07
# 1        -4569.096021 -8.508630e+06  2.203367e+07  0.754572  6.457718e-07
# 2        13792.336673  2.203367e+07 -3.237587e+07  0.754571  1.099557e-06
# 3       -13187.535942 -3.237587e+07  3.221171e+07  0.754571 -1.745326e-08
# 4        13655.539850  3.221171e+07 -3.158619e+07  0.754572 -2.635447e-06
#
#      bearing  brearing_shift  bearing_rate
# 0  90.000012       89.999951      0.000061
# 1  89.999951       89.999917      0.000034
# 2  89.999917       90.000001      0.000085
# 3  90.000001       90.000200      0.000199
# 4  90.000200       89.999973      0.000227
#
# [5 rows x 21 columns]

# %%
for i,name in enumerate(df.quantile(.40).index):
    print(i , name)
# Out:
# 0 lat
# 1 long
# 2 null
# 3 alt
# 4 DateTime
# 5 lat_shift
# 6 long_shift
# 7 time_shift
# 8 speed_mph
# 9 speed_shift
# 10 acceleration
# 11 acceleration_shift
# 12 jerk
# 13 jerk_shift
# 14 y
# 15 x
# 16 bearing
# 17 brearing_shift
# 18 bearing_rate

# %%
df.quantile(.40)
# Out:
# lat                   3.964803e+01
# long                  1.181628e+02
# null                  0.000000e+00
# alt                   1.322000e+02
# DateTime              3.972003e+04
# lat_shift             3.964803e+01
# long_shift            1.181628e+02
# time_shift            3.972003e+04
# speed_mph             1.576801e+00
# speed_shift           1.577281e+00
# acceleration         -3.026884e+02
# acceleration_shift   -3.038404e+02
# jerk                 -4.130036e+05
# jerk_shift           -4.136893e+05
# y                     7.545545e-01
# x                    -1.396263e-07
# bearing               9.000000e+01
# brearing_shift        9.000000e+01
# bearing_rate          7.951927e-06
# Name: 0.4, dtype: float64

# %%
def list_df_summary(input_df):
    names = ['speed_1','speed_25','speed_50','speed_75','speed_100','speed_ave',
            'accel_1','accel_25','accel_50','accel_75','accel_100','accel_ave',
            'jerk_1','jerk_25','jerk_50','jerk_75','jerk_100','jerk_ave',
            'bearingRate_1','bearingRate_25','bearingRate_50','bearingRate_75','bearingRate_100','bearingRate_ave']
    values = list()
    #speed
    values.append(input_df.quantile(.01)[8])
    values.append(input_df.quantile(.25)[8])
    values.append(input_df.quantile(.50)[8])
    values.append(input_df.quantile(.75)[8])
    values.append(input_df.quantile(1.0)[8])
    values.append(input_df.mean()[8])
    #accel
    values.append(input_df.quantile(.01)[10])
    values.append(input_df.quantile(.25)[10])
    values.append(input_df.quantile(.50)[10])
    values.append(input_df.quantile(.75)[10])
    values.append(input_df.quantile(1.0)[10])
    values.append(input_df.mean()[10])
    #jerk
    values.append(input_df.quantile(.01)[12])
    values.append(input_df.quantile(.25)[12])
    values.append(input_df.quantile(.50)[12])
    values.append(input_df.quantile(.75)[12])
    values.append(input_df.quantile(1.0)[12])
    values.append(input_df.mean()[12])
    #bearing
    values.append(input_df.quantile(.01)[18])
    values.append(input_df.quantile(.25)[18])
    values.append(input_df.quantile(.50)[18])
    values.append(input_df.quantile(.75)[18])
    values.append(input_df.quantile(1.0)[18])
    values.append(input_df.mean()[18])
    
    return pd.DataFrame([values],columns=names)

# %%
list_df_summary(df)
# Out:
#    speed_1  speed_25  speed_50  speed_75  speed_100  speed_ave      accel_1  \
# 0      0.0    1.0248  1.923598    2.9358  99.419925   2.461536 -9875.302737
#
#      accel_25   accel_50     accel_75  ...       jerk_50       jerk_75  \
# 0 -856.082461 -37.440106  1053.361014  ...  47941.509839  2.095636e+06
#
#        jerk_100       jerk_ave  bearingRate_1  bearingRate_25  bearingRate_50  \
# 0  1.422704e+08 -172683.572381   5.019274e-13        0.000005        0.000011
#
#    bearingRate_75  bearingRate_100  bearingRate_ave
# 0        0.000025         0.006636         0.000042
#
# [1 rows x 24 columns]

# %%
glob('/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/*/Trajectory')
# Out:
# ['/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/135/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/132/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/104/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/103/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/168/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/157/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/150/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/159/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/166/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/161/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/102/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/105/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/133/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/134/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/160/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/158/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/167/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/151/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/169/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/156/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/024/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/023/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/015/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/012/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/079/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/046/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/041/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/048/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/077/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/083/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/084/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/070/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/013/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/014/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/022/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/025/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/071/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/085/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/049/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/082/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/076/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/040/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/078/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/047/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/065/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/091/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/096/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/062/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/054/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/053/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/098/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/038/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/007/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/000/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/009/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/036/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/031/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/052/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/099/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/055/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/063/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/097/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/090/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/064/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/030/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/008/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/037/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/001/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/039/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/006/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/174/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/180/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/173/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/145/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/142/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/129/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/116/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/111/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/118/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/127/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/120/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/143/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/144/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/172/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/181/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/175/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/121/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/119/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/126/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/110/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/128/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/117/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/153/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/154/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/162/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/165/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/131/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/136/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/109/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/100/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/107/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/138/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/164/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/163/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/155/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/152/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/106/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/139/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/101/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/137/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/108/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/130/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/089/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/042/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/045/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/087/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/073/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/074/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/080/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/020/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/027/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/018/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/011/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/016/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/029/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/081/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/075/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/072/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/086/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/044/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/088/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/043/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/017/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/028/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/010/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/026/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/019/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/021/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/003/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/004/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/032/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/035/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/095/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/061/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/066/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/092/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/059/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/050/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/057/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/068/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/034/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/033/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/005/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/002/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/056/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/069/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/051/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/093/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/067/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/058/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/060/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/094/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/112/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/115/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/123/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/124/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/170/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/177/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/148/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/141/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/146/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/179/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/125/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/122/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/114/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/113/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/147/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/178/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/140/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/176/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/149/Trajectory',
#  '/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/171/Trajectory']

# %%
plts = []
for folder in glob('/Users/williamyee/Documents/Data Bootcamp/unsupervised-learning-metis/Geolife Trajectories 1.3/Data/*/Trajectory'):
    for file in glob(folder +'/*.plt'):
        plts.append(file)

# %%
large_df = []
for file in plts:
    large_df.append(list_df_summary(add_feat(pd.read_csv(file, skiprows=6,names=colnames))))
modeling_df = pd.concat(large_df)

# %%
list_df_summary(add_feat(pd.read_csv(plts[0], skiprows=6,names=colnames)))
# Out:
#    speed_1  speed_25  speed_50  speed_75  speed_100  speed_ave       accel_1  \
# 0      0.0  0.555301  2.054161  3.580425  97.443192   2.621755 -26070.993724
#
#     accel_25  accel_50    accel_75  ...       jerk_50        jerk_75  \
# 0 -564.01701       0.0  630.891418  ...  119364.89159  961596.677007
#
#        jerk_100      jerk_ave  bearingRate_1  bearingRate_25  bearingRate_50  \
# 0  3.255737e+08  1.135752e+06   2.842171e-14        0.000003        0.000011
#
#    bearingRate_75  bearingRate_100  bearingRate_ave
# 0        0.000024         0.001826         0.000021
#
# [1 rows x 24 columns]

# %%
pd.concat(large_df)
# Out:
#    speed_1  speed_25  speed_50   speed_75   speed_100  speed_ave  \
# 0      0.0  0.555301  2.054161   3.580425   97.443192   2.621755
# 0      0.0  0.718740  1.319040   2.478599   66.524440   4.644291
# 0      0.0  2.058839  4.833603  21.374955  191.668881  11.836363
#
#         accel_1     accel_25   accel_50     accel_75  ...        jerk_50  \
# 0 -26070.993724  -564.017010   0.000000   630.891418  ...  119364.891590
# 0 -88549.867755  -680.143359  13.993395   878.690258  ...  114402.265414
# 0 -96965.784376 -1396.409620  -1.162585  1243.455840  ...  128679.652968
#
#         jerk_75      jerk_100      jerk_ave  bearingRate_1  bearingRate_25  \
# 0  9.615967e+05  3.255737e+08  1.135752e+06   2.842171e-14        0.000003
# 0  1.134575e+06  3.534021e+08  5.027868e+05   1.333660e-11        0.000005
# 0  3.659706e+06  2.056361e+09  3.242991e+06   1.272923e-11        0.000003
#
#    bearingRate_50  bearingRate_75  bearingRate_100  bearingRate_ave
# 0        0.000011        0.000024         0.001826         0.000021
# 0        0.000017        0.000034         0.000372         0.000037
# 0        0.000008        0.000018         0.002325         0.000026
#
# [3 rows x 24 columns]
